# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %%
### New HDL UK/Japan Biobank trans-ethnic fine mapping set sizes
hdl_loci_df = pd.read_csv('locus_set_sizes.txt', sep='\t', index_col=0)
hdl_loci_df
# Out:
#                                                CAVIAR-Asian  CAVIAR-Euro  \
# locus_chromosome_10_bp_113440329_to_114440329            83           52
# locus_chromosome_10_bp_115286236_to_116286236            31           16
# locus_chromosome_10_bp_122398697_to_123398697            97           85
# locus_chromosome_10_bp_33136099_to_34136099             230           32
# locus_chromosome_10_bp_45522005_to_46522005              59           48
# ...                                                     ...          ...
# locus_chromosome_9_bp_107161742_to_108161742              6            3
# locus_chromosome_9_bp_123131225_to_124131225            109          121
# locus_chromosome_9_bp_139487756_to_140487756             38           32
# locus_chromosome_9_bp_14804782_to_15804782               52           11
# locus_chromosome_9_bp_94882297_to_95882297              121          101
#
#                                                PAINTOR  MsCAVIAR
# locus_chromosome_10_bp_113440329_to_114440329       58        61
# locus_chromosome_10_bp_115286236_to_116286236       18        10
# locus_chromosome_10_bp_122398697_to_123398697       53       102
# locus_chromosome_10_bp_33136099_to_34136099         48        20
# locus_chromosome_10_bp_45522005_to_46522005         38        34
# ...                                                ...       ...
# locus_chromosome_9_bp_107161742_to_108161742         5         3
# locus_chromosome_9_bp_123131225_to_124131225        70       103
# locus_chromosome_9_bp_139487756_to_140487756        33        31
# locus_chromosome_9_bp_14804782_to_15804782          14        10
# locus_chromosome_9_bp_94882297_to_95882297          98        96
#
# [185 rows x 4 columns]

# %%
sns.set_context("talk", font_scale=0.8)
figure(num=None, figsize=(8, 4), dpi=80, facecolor='w', edgecolor='k')
plt.ylabel='Causal Set Size'
ax = sns.boxplot(data=hdl_loci_df, palette='muted')
#ax.yaxis.grid(True) # Show the horizontal gridlines
# sns.swarmplot(data=hdl_loci_df, palette='muted')
ax.set(xlabel="", ylabel="Causal Set Size")
# plt.xticks(rotation=0)
plt.savefig('hdl_box_and_swarm.png', bbox_inches='tight')

# %%
# Scatter plots HDL
sns.set_context("talk", font_scale=1.0)
figure(num=None, figsize=(18, 4), dpi=80, facecolor='w', edgecolor='k')
plt.subplots_adjust(wspace = 0.3)

plt.subplot(1, 3, 1)
ax1 = sns.scatterplot(data=hdl_loci_df, x="MsCAVIAR", y="CAVIAR-Asian")
ax1.set(xlabel="", ylabel="CAVIAR-Asian Set Sizes")
ax1.set(xlim=(0, 450), ylim=(0, 450))
ax1.plot([0, 1], [0, 1], transform=ax1.transAxes, color='red')

plt.subplot(1, 3, 2)
ax2 = sns.scatterplot(data=hdl_loci_df, x="MsCAVIAR", y="CAVIAR-Euro")
ax2.set(xlabel="MsCAVIAR Set Sizes", ylabel="CAVIAR-Euro Set Sizes")
ax2.set(xlim=(0, 320), ylim=(0, 320))
ax2.plot([0, 1], [0, 1], transform=ax2.transAxes, color='red')

plt.subplot(1, 3, 3)
ax3 = sns.scatterplot(data=hdl_loci_df, x="MsCAVIAR", y="PAINTOR")
ax3.set(xlabel="", ylabel="PAINTOR Set Sizes")
ax3.set(xlim=(0, 300), ylim=(0, 300))
ax3.plot([0, 1], [0, 1], transform=ax3.transAxes, color='red')

plt.xticks(rotation=0)
plt.savefig('hdl_scatter.png', bbox_inches='tight')
